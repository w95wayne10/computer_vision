# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
lena_gray = cv2.imread('lena.bmp', cv2.IMREAD_GRAYSCALE)
cv2_imshow(lena_gray)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F0EAC0D4950>

# %%
lena_gray.shape
# Out:
# (512, 512)

# %%
upside_down_lena = lena_gray[::-1,:]
cv2_imshow(upside_down_lena)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FE4075845D0>

# %%
rightside_left_lena = lena_gray[:, ::-1]
cv2_imshow(rightside_left_lena)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FE40757CBD0>

# %%
diagonally_flip_lena = lena_gray.T
cv2_imshow(diagonally_flip_lena)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FE407648C90>

# %%
half_lena = cv2.resize(lena_gray, (256, 256), interpolation=cv2.INTER_AREA)
cv2_imshow(half_lena)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FE40752ED10>

# %%
binarize_lena = lena_gray//128*255
cv2_imshow(binarize_lena)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FE40765B4D0>

# %%
# %%writefile /content/drive/MyDrive/CVHW/HW1.py
import cv2

lena_gray = cv2.imread('lena.bmp', cv2.IMREAD_GRAYSCALE)
upside_down_lena = lena_gray[::-1, :]
rightside_left_lena = lena_gray[:, ::-1]
diagonally_flip_lena = lena_gray.T

cv2.imwrite('upside_down_lena.bmp', upside_down_lena)
cv2.imwrite('rightside_left_lena.bmp', rightside_left_lena)
cv2.imwrite('diagonally_flip_lena.bmp', diagonally_flip_lena)
# Out:
# Writing /content/drive/MyDrive/CVHW/HW1.py
